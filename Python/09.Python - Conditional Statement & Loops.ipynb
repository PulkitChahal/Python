# %%
a = 500
price = 850
if price <= 500:
    print("yes i will be able to buy")

# %%
price <= 500
# Out:
# False

# %%
850 <= 500
# Out:
# False

# %%
a = 500
price = 850
if price <= 500:
    print("yes i will be able to buy")
else:
    print("i wont be able to buy")
# Out:
# i wont be able to buy

# %%
a = 500
shirt_price = 200
pant_price = 500
coat_price = 800

if True:
    print("this is a testing block")
    
if coat_price <= a :
    print("yes i will try to buy coat")
elif pant_price < 500 :
    print("i will try to buy pant")
elif shirt_price < 500 :
    print("i will try to buy shirt")
else :
    print("i wont be able to buy")
# Out:
# this is a testing block
# i will try to buy shirt

# %%
500<500
# Out:
# False

# %%
a = 500
shirt_price = 200
pant_price = 500
coat_price = 800
my_size  = 'M'
size_store = ['L','XL','S','XXL','XXXL']
my_fav_clr = 'white'
store_clr = ['white','red','blue','orange']

if True :
    print("this is a testing bolck")
    
if coat_price <= a :
    print("yes i will try to buy coat")
elif pant_price < 500 :
    print("i will try to buy pant")
elif shirt_price < 500 :
    print("i will try to buy shirt")
else :
    print("i wont be able to buy")
# Out:
# this is a testing bolck
# i will try to buy shirt

# %%
a = 500
shirt_price = 200
pant_price = 500
coat_price = 800
my_size  = 'M'
size_store = ['L','XL','S','XXL','XXXL']
my_fav_clr = 'white'
store_clr = ['white','red','blue','orange']

if coat_price <= a :
    print("yes i will try to buy coat")
elif pant_price < 500 :
    print("i will try to buy pant")
elif shirt_price < 500 :
    print("yes its available under my budget")
    if my_size == size_store :
        print("i will try to buy shirt")
        if my_fav_clr in store_clr:
            print("yes i will try to choose it")
        else :
            print("my fav clr is not available i will move to another store")
    else :
        print("my size is not available")
else :
    print("i wont be able to buy")
# Out:
# yes its available under my budget
# my size is not available

# %%
my_size = size_store

# %%
'M' in size_store
# Out:
# False

# %%
course = ['DSM','DSA','java','Big data','DA']
price = 20000
mentor = "sudhanshu kumar"

if 'DSM' in course and price == 20000 and "sudhanshu kumar" == mentor:
    print("yes i am doing this course ")
# Out:
# yes i am doing this course

# %%
course = ['DSM','DSA','java','Big data','DA']
price = 20000
mentor = "sudhanshu kumar"

if 'DSM' in course and price == 1000 and "sudhanshu kumar" == mentor:
    print("yes i am doing this course ")

# %%
course_price = 20000
if 10000<=course_price<=15000:
    print("i will try to buy a course")
else :
    print("its out of my budget")
# Out:
# its out of my budget

# %%
10000<= course_price <=15000
# Out:
# False

# %%
user_name = "sudh"
password = "sudh@1234"

if user_name == input("enter your username ") and password == input("enter your password "):
    print("you have logged in successfully")
else :
    print("enetr correct username and password")
# Out:
# enter your username sudh
# enter your password sudh@1234
# you have logged in successfully

# %%
user_name = "sudh"
password = "sudh@1234"

if user_name == input("enter your username ") or password == input("enter your password "):
    print("you have logged in successfully")
else :
    print("enetr correct username and password")
# Out:
# enter your username sudh
# you have logged in successfully

# %%
mobile_no = 123456
otp = 1234

if mobile_no == int(input("enter your registered mobile no ")):
    print("yes you are a registered user")
    if otp == int(input("enter otp that we have sent on your mobile no")):
        print("you have logged in successfully")
    else:
        print("otp is not correct please try to enter again")
else :
    print("you have not entered a valid mobile no")
# Out:
# enter your registered mobile no 123456
# yes you are a registered user
# enter otp that we have sent on your mobile no164
# otp is not correct please try to enter again

# %%
mobile_no = {22466,3465,6464563,5454636,5544161,131364,12546,123456,654321}
otp = 1234

if int(input("enter your registered mobile no ")) in mobile_no:
    print("yes you are a registered user")
    if otp == int(input("enter otp that we have sent on your mobile no ")):
        print("you have logged in successfully")
    else:
        print("otp is not correct please try to enter again")
else :
    print("you have not entered a valid mobile no")
# Out:
# enter your registered mobile no 123456
# yes you are a registered user
# enter otp that we have sent on your mobile no1234
# you have logged in successfully

# %%
l = [12,3,3,4,5,6,6]

for i in l:
    print(i)
# Out:
# 12
# 3
# 3
# 4
# 5
# 6
# 6

# %%
l = [12,3,3,4,5,6,6]

for i in l:
    print(i+2)
# Out:
# 14
# 5
# 5
# 6
# 7
# 8
# 8

# %%
l = [12,3,3,4,5,6,6]
mobile_no = {22466,3465,6464563,5454636,5544161,131364,12546,123456,654321}
stu_mo = 131364
for i in mobile_no:
    print(i)
    if i ==stu_mo:
        print("yes user is registered")
# Out:
# 123456
# 5544161
# 22466
# 12546
# 131364
# yes user is registered
# 3465
# 5454636
# 654321
# 6464563

# %%
l = [12,3,3,4,5,6,6]
mobile_no = {22466,3465,6464563,5454636,5544161,131364,12546,123456,654321}
stud_mo = 131364
stud_details = {'mobile_no' :131364,'course' : ['dsa','dsm','big data']}

for i in mobile_no:
    print(i)
    if i ==stud_mo:
        print("yes user is registered")
        if i ==stud_details['mobile_no']:
            print("yes student details are available in DB ")
            print("course accessed to this user is",stud_details['course'])
# Out:
# 123456
# 5544161
# 22466
# 12546
# 131364
# yes user is registered
# yes student details are available in DB
# course accessed to this user is ['dsa', 'dsm', 'big data']
# 3465
# 5454636
# 654321
# 6464563

# %%
t = {12,3,4,5,56,"sudh","kumar"}

for i in t:
    print(i)
# Out:
# 3
# 4
# 5
# 56
# sudh
# 12
# kumar

# %%
t = {12,3,4,5,56,"sudh","kumar"}

for i in t:
    if type(i) == str:
        print(i)
# Out:
# sudh
# kumar

# %%
t = {12,3,4,5,56,"sudh","kumar"}

for i in t:
    if type(i) == int:
        print(i)
# Out:
# 3
# 4
# 5
# 56
# 12

# %%
t = {12,3,4,5,56,"sudh","kumar"}
l_int = []
l_str = []

for i in t:
    if type(i) == str:
        l_str.append(i)
    elif type(i) == int:
        l_int.append(i)
print(l_int)
print(l_str)
# Out:
# [3, 4, 5, 56, 12]
# ['sudh', 'kumar']

# %%
l_int
# Out:
# [3, 4, 5, 56, 12]

# %%
l_str
# Out:
# ['sudh', 'kumar']

# %%
s = {3,4,5,56,76,7,7,8,9}

# %%
s
# Out:
# {3, 4, 5, 7, 8, 9, 56, 76}

# %%
for i in s:
    print(i)
# Out:
# 3
# 4
# 5
# 7
# 8
# 9
# 76
# 56

# %%
d = {"name":"sudh","class" : ["big data","data analytics","data science","DSA","architecture","system design"],"mobile_no": 345353453,"email_id" : "sskumari787y@gmail.com"}

# %%
d
# Out:
# {'name': 'sudh',
#  'class': ['big data',
#   'data analytics',
#   'data science',
#   'DSA',
#   'architecture',
#   'system design'],
#  'mobile_no': 345353453,
#  'email_id': 'sskumari787y@gmail.com'}

# %%
d.values()
# Out:
# dict_values(['sudh', ['big data', 'data analytics', 'data science', 'DSA', 'architecture', 'system design'], 345353453, 'sskumari787y@gmail.com'])

# %%
for i in d.values():
    print(i)
# Out:
# sudh
# ['big data', 'data analytics', 'data science', 'DSA', 'architecture', 'system design']
# 345353453
# sskumari787y@gmail.com

# %%
for i in d.values():
    if type(i) == list:
        print(i)
# Out:
# ['big data', 'data analytics', 'data science', 'DSA', 'architecture', 'system design']

# %%
for i in d.values():
    if type(i) == list:
        if 'system design' in i :
            print("yes this mentor teach system design")
# Out:
# yes this mentor teach system design
