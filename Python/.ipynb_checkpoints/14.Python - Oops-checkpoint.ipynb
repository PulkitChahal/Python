# %%
1 + 2
# Out:
# 3

# %%
a = 10
b = 20
c = 50

# %%
s = "sudh"

# %%
class bankaccount :
    
    def openaccount(self, name, email_id):
        print("open an account by taking name and mail id")
        return name+' '+email_id
    
    def deposite(self, amount):
        print("i am trying to deposite an amount in my account")
        
    def withdraw(self, amt_with):
        print("withdraw the amount")
        
    def update_details(self, name_update, email_update):
        print("this function will update my name and mail id for account")

# %%
sudh = bankaccount()

# %%
sudh.openaccount("sudhanshu","sudhanshu@gmail.com")
# Out:
# open an account by taking name and mail id
# 'sudhanshu sudhanshu@gmail.com'

# %%
def openaccount( name, email_id):
        print("open an account by taking name and mail id")
        return name + email_id

# %%
openaccount("sudh","sudh@gmail.com")
# Out:
# open an account by taking name and mail id
# 'sudhsudh@gmail.com'

# %%
class list_ops:
    
    def extractfromindex(self, l, index):
        return l[index]
    
    def extractrangedata(self, l, start, end):
        return l[start:end]
    
    def extracteven(self, l):
        l1=[]
        for i in l:
            if i%2 == 0:
                l1.append(i)
        return l1

# %%
first_obj = list_ops()
first_obj.extractfromindex([2,3,4,5,6], 4)
# Out:
# 6

# %%
first_obj.extractrangedata([2,34,5,6,7,8], 0, 4)
# Out:
# [2, 34, 5, 6]

# %%
first_obj.extracteven([1,2,3,4,5,6,7,8,9])
# Out:
# [2, 4, 6, 8]

# %%
l = [4,5,6,7,7]
l[3]
# Out:
# 7

# %%
class list_ops:
    
    a = 10
    l = [4,5,7,7,8,9,9]
    
    def extractfromindex(sudh, l, index):
        return l[index]
    
    def extractrangedata(sudh, l, start, end):
        return l[start:end]
    
    def extracteven(sudh, l):
        l1=[]
        for i in l:
            if i%2 == 0:
                l1.append(i)
        return l1

# %%
first_obj = list_ops()
first_obj.extractfromindex([2,2,3,4,5,6], 4)
# Out:
# 5

# %%
first_obj.a
# Out:
# 10

# %%
first_obj.l
# Out:
# [4, 5, 7, 7, 8, 9, 9]

# %%
first_obj = list_ops()
first_obj.extractfromindex(first_obj.l, 4)
# Out:
# 8

# %%
second_obj = list_ops()
second_obj.l
# Out:
# [4, 5, 7, 7, 8, 9, 9]

# %%
third_obj = list_ops()
third_obj.l
# Out:
# [4, 5, 7, 7, 8, 9, 9]

# %%
# __init__ -> dundar function or inbuilt function
# __init__ is a constructor method

class list_ops:    
    #a = 10
    #l = [4,5,7,7,8,9,9]
    def __init__(sudh, l):
        sudh.l = l
        sudh.l1 = l
        sudh.l2 = 40
        sudh.l3 = "sudh"
        sudh.l4 = (4,5,6,6,7,8)
        sudh.l5 ={"key":"value"}
        
    def extractfromindex(sudh, l, index):
        return l[index]
    
    def extractrangedata(sudh, l, start, end):
        return l[start:end]
    
    def extracteven(sudh, l):
        l1=[]
        for i in l:
            if i%2 == 0:
                l1.append(i)
        return l1

# %%
second_obj = list_ops([3,4,5,6,7,8])
second_obj.l
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
second_obj = list_ops([3,4,5,6,7,8])
second_obj.l2
# Out:
# 40

# %%
second_obj = list_ops([3,4,5,6,7,8])
second_obj.l5
# Out:
# {'key': 'value'}

# %%
third_obj = list_ops([3,4,5,6,7,8])
third_obj.l1
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
third_obj = list_ops([3,4,5,6,7,8])
third_obj.l2
# Out:
# 40

# %%
third_obj = list_ops([3,4,5,6,7,8])
third_obj.l3
# Out:
# 'sudh'

# %%
third_obj = list_ops(20)
third_obj.l2
# Out:
# 40

# %%
class book:    
    def __init__(self, name, title, pageno):
        self.name_of_book = name
        self.title_of_book = title
        self.page_no = pageno
        
    def extract_details(self):
        print(self.name_of_book, self.title_of_book)
    
    def print_page_no(self):
        print(self.page_no)

# %%
sudhanshu = book('dsa', 'practical dsa', 456)
ronik = book("data science", 'emplementation of data science', 345)
wasim = book('big data', 'invention with big data', 434)

# %%
sudhanshu.extract_details()
# Out:
# dsa practical dsa

# %%
sudhanshu.name_of_book
# Out:
# 'dsa'

# %%
sudhanshu.title_of_book
# Out:
# 'practical dsa'

# %%
sudhanshu.page_no
# Out:
# 456

# %%
ronik.extract_details()
# Out:
# data science emplementation of data science

# %%
wasim.extract_details()
# Out:
# big data invention with big data

# %%
a = 10
b = 60
c = 40

# %%
class book:    
    def __init__(self):
        self.name_of_book = "dsa"
        self.title_of_book = "dsa advance"
        self.page_no = 5646
        
    def extract_details(self):
        print(self.name_of_book, self.title_of_book)
    
    def print_page_no(self):
        print(self.page_no)

# %%
student1 = book()

# %%
student1.name_of_book
# Out:
# 'dsa'

# %%
stud2 = book()
stud2.name_of_book
# Out:
# 'dsa'

# %%
class gmail_ops:
    def __init__(self, userid, password):
        self.userid = userid
        self.password = password
        self.url = "https://gmail.com"
    
    def login(self):
        print("take userid " + self.userid + " take password " + self.password + " hit url " + self.url)
        print("login")
    
    def read_mail(self):
        print("read mail for " + self.userid + " " + self.password)
    
    def reply_mail(self):
        print("reply mail for " + self.userid + " " + self.password)

# %%
user1 = gmail_ops("user1", "user1pass")
user1.login()
# Out:
# take userid user1 take password user1pass hit url https://gmail.com
# login

# %%
user2 = gmail_ops("user2", "user2pass")
user2.login()
# Out:
# take userid user2 take password user2pass hit url https://gmail.com
# login

# %%
from functools import reduce
class calculator:
    def add(self, *args):
        return sum(args)
    
    def subtraction(self, *args):
        return reduce(lambda a,b : a-b , args)
    
    def mul(self, *args):
        return reduce(lambda a,b : a*b , args)
    
    def div(self, *args):
        return reduce(lambda a,b : a/b , args)

# %%
himanshu = calculator()

# %%
himanshu.add(3,4,5,6,7)
# Out:
# 25

# %%
himanshu.subtraction(4,56,67)
# Out:
# -119

# %%
himanshu.mul(4,5,6)
# Out:
# 120

# %%
himanshu.div(5,9,8)
# Out:
# 0.06944444444444445

# %%
karan = calculator()

# %%
karan.add(4,56,4,8)
# Out:
# 72

# %%
from functools import reduce
class calculator:
    
    def __init__(self, username):
        self.username = username
    def add(self, *args):
        return self.username, sum(args)
    
    def subtraction(self, *args):
        return self.username, reduce(lambda a,b : a-b , args)
    
    def mul(self, *args):
        return self.username, reduce(lambda a,b : a*b , args)
    
    def div(self, *args):
        return self.username, reduce(lambda a,b : a/b , args)

# %%
himanshu = calculator("chulbul pandey")

# %%
himanshu.add(3,4,5,6,7)
# Out:
# ('chulbul pandey', 25)

# %%
himanshu.subtraction(4,56,67)
# Out:
# ('chulbul pandey', -119)

# %%
himanshu.mul(4,5,6)
# Out:
# ('chulbul pandey', 120)

# %%
himanshu.div(5,9,8)
# Out:
# ('chulbul pandey', 0.06944444444444445)
