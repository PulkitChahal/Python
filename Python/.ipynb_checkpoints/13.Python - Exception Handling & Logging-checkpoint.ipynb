# %%
a = int(input("enetr a value for a "))
b = int(input("enter a value for b "))
# Out:
# enetr a value for a 6
# enter a value for b 0

# %%
a*b
# Out:
# 0

# %%
a/b
print("print something")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a/b
#       2 print("print something")
#
# ZeroDivisionError: division by zero

# %%
a+b
# Out:
# 6

# %%
l = [4,5,6,7,8,9,0]
l1 = []
def even_parser(l):
    for i in l :
        if i%2 == 0:
            l1.append(i)
    return l1

# %%
even_parser(6)
print("print something")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 even_parser(6)
#       2 print("print something")
#
# Cell In[13], line 4, in even_parser(l)
#       3 def even_parser(l):
# ----> 4     for i in l :
#       5         if i%2 == 0:
#       6             l1.applend(i)
#
# TypeError: 'int' object is not iterable

# %%
try:
    a = int(input("enetr a value for a "))
    b = int(input("enter a value for b "))
    c = a/b
    print(c)
except:
    pass
# Out:
# enetr a value for a 4
# enter a value for b 2
# 2.0

# %%
l = [4,5,6,7,8,9,0]
l1 = []
def even_parser(l):
    try:
        for i in l :
            if i%2 == 0:
                l1.append(i)
        return l1
    except:
        pass
    print("no problem")

# %%
even_parser(6)
print("465652")
# Out:
# no problem
# 465652

# %%
try:
    c = 6/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
c = 6/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 c = 6/0
#
# ZeroDivisionError: division by zero

# %%
try :
    a = int(input())
    b = int(input())
    c = a/b
except Exception as e :
    print(e)
# Out:
# 3
# 0
# division by zero

# %%
try :
    a = int(input())
    b = int(input())
    c = a/b
except TypeError as t :
    print(t)
except ZeroDivisionError as z :
    print(z)
# Out:
# cdsfcs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 try :
# ----> 2     a = int(input())
#       3     b = int(input())
#       4     c = a/b
#
# ValueError: invalid literal for int() with base 10: 'cdsfcs'

# %%
try :
    a = int(input())
    b = int(input())
    c = a/b
except TypeError as t :
    print(t)
except ZeroDivisionError as z :
    print(z)
except ValueError as v :
    print(v)
# Out:
# ds
# invalid literal for int() with base 10: 'ds'

# %%
try:
    x = 5/0
except ZeroDivisionError as z:
    print(z)
    y = int("sudh")
# Out:
# division by zero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 try:
# ----> 2     x = 5/0
#       3 except ZeroDivisionError as z:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 5
#       3 except ZeroDivisionError as z:
#       4     print(z)
# ----> 5     y = int("sudh")
#
# ValueError: invalid literal for int() with base 10: 'sudh'

# %%
try:
    x = 5/0
except ZeroDivisionError as z:
    print(z)
    try:
        y = int("sudh")
    except ValueError as v:
        print(v)
# Out:
# division by zero
# invalid literal for int() with base 10: 'sudh'

# %%
try:
    x = 5/0
except ZeroDivisionError as z:
    print(z)
else:
    print("this will execute once try will execute witjout error")
# Out:
# division by zero

# %%
try:
    x = 5/1
except ZeroDivisionError as z:
    print(z)
else:
    print("this will execute once try will execute witjout error")
# Out:
# this will execute once try will execute witjout error

# %%
try:
    x = 5/0
except ZeroDivisionError as z:
    print(z)
else:
    print("this will execute once try will execute witjout error")
finally:
    print("this will be executed always")
# Out:
# division by zero
# this will be executed always

# %%
try:
    d = {"name":"sudh","mobile_no":12345,"email_id":"sudh@gmail.com"}
    d["course"]
except Exception :
    print("this is keyerror")
# Out:
# this is keyerror

# %%
d
# Out:
# {'name': 'sudh', 'mobile_no': 12345, 'email_id': 'sudh@gmail.com'}

# %%
try:
    l = [4,5,6,7,7,8]
    l[10]
except Exception as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    a = "sudh"
    int(a)
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'sudh'

# %%
file_name = "test.txt"
f = open(file_name)
f.read()
# Out:
# 'python class to learn by pw skills'

# %%
ls -l
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E44B-A095
#
#  Directory of C:\Users\pulki\PW Python\Python
# File Not Found

# %%
ls - l
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 685A-1AAE
#
#  Directory of C:\Users\DELL\PW Python
#
#
#  Directory of C:\Users\DELL\PW Python
# File Not Found

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\PW Python'

# %%
file_name = "C:\\Users\\DELL\\PW Python\\test.txt"
f = open(file_name)
f.read()
# Out:
# 'python class to learn by pw skills'

# %%
try :
    file_name = "C:\\Users\\DELL\\PW Python\\test.txt"
    f = open(file_name)
    f.read()
except Exception as e:
    print(e)

# %%
open('C:/Users/DELL/PW Python/test.txt')
# Out:
# <_io.TextIOWrapper name='C:/Users/DELL/PW Python/test.txt' mode='r' encoding='cp1252'>

# %%
cd task
# Out:
# [WinError 2] The system cannot find the file specified: 'task'
# C:\Users\DELL\PW Python

# %%
cd Task
# Out:
# [WinError 2] The system cannot find the file specified: 'Task'
# C:\Users\DELL\PW Python

# %%
cd Questions
# Out:
# C:\Users\DELL\PW Python\Questions

# %%
cd Task
# Out:
# [WinError 2] The system cannot find the file specified: 'Task'
# C:\Users\DELL\PW Python\Questions

# %%
cd Task1
# Out:
# C:\Users\DELL\PW Python\Questions\Task1

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\PW Python\\Questions\\Task1'

# %%
cd ...
# Out:
# C:\Users\DELL\PW Python

# %%
cd ...
# Out:
# C:\Users\DELL

# %%
pwd
# Out:
# 'C:\\Users\\DELL'

# %%
cd PW Python
# Out:
# C:\Users\DELL\PW Python

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\PW Python'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 685A-1AAE
#
#  Directory of C:\Users\DELL\PW Python
#
# 20-12-2023  21:42    <DIR>          .
# 20-12-2023  20:44    <DIR>          ..
# 17-12-2023  17:26    <DIR>          .ipynb_checkpoints
# 09-12-2023  14:02            32,672 03.Python basic variables.ipynb
# 09-12-2023  18:44            83,164 04.Python basic data type.ipynb
# 10-12-2023  11:10            28,679 05.Operators.ipynb
# 10-12-2023  13:44            40,965 06.Operators And Control Flow.ipynb
# 10-12-2023  17:54            31,767 07.Python - Introduction To Functions.ipynb
# 10-12-2023  23:06            38,889 08.Python - Lambda Functions.ipynb
# 16-12-2023  16:12            19,543 09.Python - Conditional Statement & Loops.ipynb
# 16-12-2023  22:15            46,190 10.For Loop, Lambda, Map, Reduce, Filter, Recursion.ipynb
# 17-12-2023  13:28            16,086 11.Python - While Loop, Break.ipynb
# 17-12-2023  17:17            30,923 12.Python - For Loop Functions.ipynb
# 20-12-2023  21:42            20,884 13.Python - Exception Handling & Logging.ipynb
# 19-12-2023  13:23    <DIR>          Questions
# 17-12-2023  17:06                34 test.txt
#               12 File(s)        389,796 bytes
#                4 Dir(s)  97,083,011,072 bytes free

# %%
try:
    n = int(input("enter a number "))
    div = 342/n
    print(div)
except ValueError : 
    print("user has entered invalid input")
except ZeroDivisionError :
    print("user has entered zero")
# Out:
# enter a number daf
# user has entered invalid input

# %%
try:
    try:
        n = int(input("enter a number "))
        div = 342/n
        print(div)
    except ZeroDivisionError :
        print("user has entered zero")
except ValueError : 
    print("user has entered invalid input")
# Out:
# enter a number csdf
# user has entered invalid input

# %%
try:
    n = int(input("enter a number "))
    div = 342/n
    print(div)
except (ValueError, ZeroDivisionError) : 
    print("user has entered invalid input OR may be zero")
# Out:
# enter a number edf
# user has entered invalid input OR may be zero

# %%
try:
    n = int(input("enter a number "))
    div = 342/n
    print(div)
except Exception : 
    print("user has entered invalid input OR may be zero")
# Out:
# enter a number eaf
# user has entered invalid input OR may be zero

# %%
try:
    n = int(input("enter a number "))
    div = 342/n
    print(div)
except Exception :
        print("user has entered invalid input OR may be zero")
else :
    print(div)
# Out:
# enter a number fsfc
# user has entered invalid input OR may be zero

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\PW Python'

# %%
f = open('C:\\Users\\DELL\\PW Python\\test.txt')
f.read()
f.close()

# %%
f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\DELL\\PW Python\\test.txt' mode='r' encoding='cp1252'>

# %%
try:
    f = open('C:\\Users\\DELL\\PW Python\\test.txt')
    data = f.write()
except Exception:
    print("there is some issue")
else :
    print(data)
finally :
    print(data)
    f.close()
    print("file closed")
# Out:
# there is some issue
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 9
#       7     print(data)
#       8 finally :
# ----> 9     print(data)
#      10     f.close()
#      11     print("file closed")
#
# NameError: name 'data' is not defined

# %%
f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\DELL\\PW Python\\test.txt' mode='r' encoding='cp1252'>

# %%
try:
    f = open('C:\\Users\\DELL\\PW Python\\test.txt')
    data = f.write()
except Exception:
    print("there is some issue")
else :
    print(data)
finally :
    try :
        print(data)
    except :
        pass
    f.close()
    print("file closed")
# Out:
# there is some issue
# file closed

# %%
try : 
    a = int(input("enter height of teh wall "))
    if a < 0 :
        raise ValueError("enter height is negative")
except ValueError as v :
    print(v)
# Out:
# enter height of teh wall -34
# enter height is negative

# %%
try :
    age = int(input("enter your age "))
    if age < 0 :
        raise ValueError("user has entered a negative age which is not valid")
    elif age < 18 :
        raise ValueError("user is underage")
    else :
        print("valid user")
except ValueError as v :
    print(v)
# Out:
# enter your age -78
# user has entered a negative age which is not valid

# %%
import logging as log

# %%
log.basicConfig(filename = 'test.log',level = log.INFO)

# %%
log.info("store a msg")

# %%
log.debug("this is a debug msg")

# %%
log.warning("this is my warning")

# %%
log.error("this is a error msg")

# %%
log.critical("this is a critical msg")

# %%
import logging
logging.basicConfig(filename ='trytest.log',level = logging.DEBUG , format = '%(asctime)s - %(levelname)s - %(message)s')
try :
    logging.info("this is a start of program")
    logging.info("asking user to enter age")
    age = int(input("enter your age "))
    logging.info("user has entered the age = %d",age)
    if age < 0 :
        logging.info("i am checking negative condition")
        raise ValueError("user has entered a negative age which is not valid")
    elif age < 18 :
        logging.info("i am trying to check underage condition")
        raise Exception("user is underage")
    else :
        logging.info("valid user")
except Exception as e :
    logging.error(e)
# Out:
# enter your age 30

# %%
import logging
logging.basicConfig(filename ='even_parse.log',level = logging.DEBUG , format = '%(asctime)s- %(levelname)s - %(message)s')
l = [4,5,6,7,8,9,0]
logging.info(l)
l1 = []
def even_parser(l):
    try:
        logging.info("inside try block")
        for i in l :
            logging.info("inside for loop i  = %d",i)
            if i%2 == 0:
                logging.info("checking the value of i ")
                l1.append(i)
                logging.info("appending the value i = %d",i)
        return l1
    except Exception as e:
        logging.error(e)

# %%
even_parser(l)
# Out:
# [4, 6, 8, 0]
