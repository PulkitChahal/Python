# %%
#Polymorphism

# %%
def test(a,b):
    return a+b

# %%
test(3,4)
# Out:
# 7

# %%
test("sudh","kumar")
# Out:
# 'sudhkumar'

# %%
class pwskills:
    def student(self):
        pass

class datascience(pwskills):
    def student(self):
        print("this will give me a details about data science student")
    
class bigdata(pwskills):
    def student(self):
        print("this will give me a details about big data student")
        
yash = datascience()
farhana = bigdata()
yash.student()
farhana.student()
# Out:
# this will give me a details about data science student
# this will give me a details about big data student

# %%
pw = pwskills()
pw.student()

# %%
class bigdata:
    def __init__(self, number_of_class, number_of_student):
        self.number_of_class = number_of_class
        self.number_of_student = number_of_student
    
    def __add__(self, other):
        return bigdata(self.number_of_class + other.number_of_class, self.number_of_student + other.number_of_student)
    
c1 = bigdata(1,10)
c2 = bigdata(2,12)
c3 = bigdata(2,12)
result = c1+c2+c3
print(result.number_of_class, result.number_of_student)
# Out:
# 5 34

# %%
print(c1)
# Out:
# <__main__.bigdata object at 0x0000016A31ABFFD0>

# %%
print(c2)
# Out:
# <__main__.bigdata object at 0x0000016A31ABE210>

# %%
print(result)
# Out:
# <__main__.bigdata object at 0x0000016A31ABCC50>

# %%
class datascience:
    def student(self):
        print("this will give me a details about data science student")

# %%
o1 = datascience()
o2 = datascience()
o3 = datascience()
r = o1+o2+o3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 o2 = datascience()
#       3 o3 = datascience()
# ----> 4 r = o1+o2+o3
#
# TypeError: unsupported operand type(s) for +: 'datascience' and 'datascience'

# %%
class datascience:
    def student(self):
        print("this will give me a details about data science student")
    
class bigdata:
    def student(self):
        print("this will give me a details about big data student")

def output_class(class_obj):
    return class_obj.student()

# %%
sesha = datascience()
sashi = bigdata()

# %%
output_class(sesha)
# Out:
# this will give me a details about data science student

# %%
output_class(sashi)
# Out:
# this will give me a details about big data student

# %%
class pwskills:
    def student(self):
        pass

class datascience(pwskills):
    def student(self):
        print("this will give me a details about data science student")

# %%
ujwal = datascience()
ujwal.student()
# Out:
# this will give me a details about data science student

# %%
len("sudh")
# Out:
# 4

# %%
len([2,3,4,5,6,])
# Out:
# 5

# %%
#Encapsulation - detail hiding

# %%
class test:
    def __init__(self):
        self.x = "sudh"

# %%
t1 = test()

# %%
t1.x
# Out:
# 'sudh'

# %%
class test:
    def __init__(self):
        self.__x = "sudh"

# %%
t1 = test()

# %%
t1._test__x
# Out:
# 'sudh'

# %%
class test:
    def __init__(self):
        self.__x = "sudh"
        self.y = "kumar"
        self.z = "pwskills"
        
    def __test_meth(self):
        return "this is just a test"
    
    def access_var(self):
        return self.__x
    
    def update_var(self, data):
        self.__x = data

# %%
t1 = test()

# %%
t1._test__x
# Out:
# 'sudh'

# %%
t1._test__test_meth()
# Out:
# 'this is just a test'

# %%
t1.access_var()
# Out:
# 'sudh'

# %%
t1.update_var(2344567)

# %%
t1.access_var()
# Out:
# 2344567

# %%
class test:
    def __init__(self):
        self._x = "sudh"
        self.y = "kumar"
        self.z = "pwskills"
        
    def __test_meth(self):
        return "this is just a test"
    
    def access_var(self):
        return self._x
    
    def update_var(self, data):
        self._x = data

# %%
t1 = test()

# %%
t1._x
# Out:
# 'sudh'

# %%
class bank:
    def __init__(self, account_number, balance):
        self._account_number = account_number
        self.__balance = balance
    
    def check_balance(self, password):
        if password == "mysecurepass":
            return self.__balance
        else:
            return "incorrect password"
    
sudh = bank(23442, 34554)
sudh.check_balance("mysecurepass")
# Out:
# 34554

# %%
class queue:
    def __init__(self):
        self._queue = []
        
    def enqueue(self, data):
        self._queue.append(data)
    
    def dequeue(self):
        if self._queue:
            return self._queue.pop(0)
        else:
            print("its empty")
        
    def showdata(self):
        return self._queue

# %%
q = queue()

# %%
q.dequeue()
# Out:
# its empty

# %%
q.enqueue(40)

# %%
q.showdata()
# Out:
# [40]

# %%
l = [3,4,5,6]

# %%
l.pop()
# Out:
# 6

# %%
#Abstraction

# %%
class pwskills:
    def student_details(self):
        return "this will give you a student details"

# %%
from abc import ABC , abstractmethod
class pwskills:
    @abstractmethod
    def databaseconnect(self):
        pass
    @abstractmethod
    def checkuserenrollment(self, user_mailid):
        pass
    @abstractmethod
    def check_completed_lecture(self, user_id, class_id):
        pass
    @abstractmethod
    def check_lab_usases(self, user_id):
        pass
    @abstractmethod
    def check_internship(self,user_id):
        pass

# %%
class databaseconnect(pwskills):
    def databaseconnect(self):
        print("this is a implementation of database connect")
        
    def checkuserenrollment(self, user_mailid):
        return "test"
    
    def check_completed_lecture(self, user_id, class_id):
        return "test"
    
    def check_lab_usases(self, user_id):
        return "test"
    
    def check_internship(self, user_id):
        return "test"

# %%
db1 = databaseconnect()

# %%
db1.databaseconnect()
# Out:
# this is a implementation of database connect

# %%
class calculation:
    def add(x,y):
        return x+y
    
    def sub(x,y):
        return x-y
    
    def div(self, x,y):
        return x/y

# %%
a = calculation()

# %%
a.add(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 a.add(3,4)
#
# TypeError: calculation.add() takes 2 positional arguments but 3 were given

# %%
calculation.add(3,4)
# Out:
# 7

# %%
calculation.div(4,4,5)
# Out:
# 0.8

# %%
calculation.div(4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 calculation.div(4,5)
#
# TypeError: calculation.div() missing 1 required positional argument: 'y'

# %%
calculation.div(_,4,5)
# Out:
# 0.8

# %%
a.div(5,6)
# Out:
# 0.8333333333333334

# %%
b = calculation()
b.div(4,7)
# Out:
# 0.5714285714285714

# %%
class calculation:
    @staticmethod
    def add(x,y):
        return x+y
    
    @staticmethod
    def sub(x,y):
        return x-y
    
    def div(self, x,y):
        return x/y

# %%
calculation.add(3,4)
# Out:
# 7

# %%
calculation.sub(5,4)
# Out:
# 1

# %%
class cal(calculation):
    pass

# %%
cal.add(4,5)
# Out:
# 9

# %%
cal.sub(5,4)
# Out:
# 1

# %%
class cal(calculation):
    def add(x,y):
        return x+y

# %%
c1 = cal()
c1.add(4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 2
#       1 c1 = cal()
# ----> 2 c1.add(4,5)
#
# TypeError: cal.add() takes 2 positional arguments but 3 were given

# %%
class file_ops:
    def __init__(self, filename):
        self.filename = filename
        
    def read_file(self):
        with open(self.filename, 'r') as file:
            return file.read()
    
    def write_file(self, data):
        with open(self.filename, 'w') as file:
            file.write(data)

# %%
sudh_op_file = file_ops("sudhfile.txt")
sudh_op_file.write_file("sdfgdfgfsdsf sdgdd")

# %%
kapil = file_ops('kapil.txt')
kapil.write_file("this is kapil file")

# %%
kapil.read_file()
# Out:
# 'this is kapil file'

# %%
#Composition

# %%
class pwskills:
    def student(self):
        return "student details"
    
class datascience:
    def __init__(self):
        self.student = pwskills()

# %%
ds = datascience()

# %%
ds.student.student()
# Out:
# 'student details'

# %%
ds.student

# %%
class data:
    def __init__(self, mentor_name):
        self.mentor_name = mentor_name
        
class webdev:
    def __init__(self, mentor, lecture_name):
        self.mentor = mentor
        self.lecture_name = lecture_name

# %%
d = data("sudh")
w = webdev("krish",'css')

# %%
d.mentor_name
# Out:
# 'sudh'

# %%
w.mentor
# Out:
# 'krish'

# %%
d = data("sudh")
w = webdev(d,'css')

# %%
d.mentor_name
# Out:
# 'sudh'

# %%
w.mentor

# %%
w.mentor.mentor_name
# Out:
# 'sudh'

# %%
l = [3,4,5,6]
l1 = [4,5,6,7,8]
l3 = ["sudh","kumar","pwskills","krish"]

# %%
list(zip(l,l1,l3))
# Out:
# [(3, 4, 'sudh'), (4, 5, 'kumar'), (5, 6, 'pwskills'), (6, 7, 'krish')]

# %%
l = (3,4,5,6)
l1 = [4,5,6,7,8]
l3 = ["sudh","kumar","pwskills","krish"]

# %%
list(zip(l,l1,l3))
# Out:
# [(3, 4, 'sudh'), (4, 5, 'kumar'), (5, 6, 'pwskills'), (6, 7, 'krish')]

# %%
l3
# Out:
# ['sudh', 'kumar', 'pwskills', 'krish']

# %%
for index, data in enumerate(l3):
    print(index," ",data)
# Out:
# 0   sudh
# 1   kumar
# 2   pwskills
# 3   krish
