# %%
'''
1. NUMERIC = INT, FLOAT, COMPLEX
2. STRING = STR
3. LIST
TUPLE
DICT
SETS
'''
# Out:
# '\n1. NUMERIC = INT, FLOAT, COMPLEX\n2. STRING = STR\n3. LIST\nTUPLE\nDICT\nSETS\n'

# %%
x = 10

# %%
x=1.34

# %%
x="imarn"

# %%
x=['hi',4,3.14]

# %%
y={'name':'imran'}

# %%
h={1,2,3,5}

# %%
type(y)
# Out:
# dict

# %%
x=input()
# Out:
# 234

# %%
type(h)
# Out:
# set

# %%
y=input()
# Out:
# 5

# %%
w=input("enter your name ")
# Out:
# enter your name imran

# %%
w
# Out:
# 'imran'

# %%
print('hi')
# Out:
# hi

# %%
x=input("enter your name ")
print(x)
# Out:
# enter your name pwskills
# pwskills

# %%
y =input("enter your age ")
print("your age is "+y)
# Out:
# enter your age 45
# your age is 45

# %%
x=10
y=30
print(x+y)
# Out:
# 40

# %%
x=int(input("enter first number: "))
y=int(input("enter second number: "))
print(x+y)
# Out:
# enter first number: 5
# enter second number: 6
# 11

# %%
print("pwskills")
# Out:
# pwskills

# %%
x="hi"
y="pwskills"
print(f"{x} {y}")
# Out:
# hi pwskills

# %%
x="hi"
y="pwskills"
print(f"{x} hello {y}")
# Out:
# hi hello pwskills

# %%
x="hi"
y="pwskills"
print(f"{x}{y}")
# Out:
# hipwskills

# %%
print("pw")
# Out:
# pw

# %%
print("s")
# Out:
# s

# %%
print("{0} and {1} ".format("pw","skills"))
# Out:
# pw and skills

# %%
print("{1} and {0} ".format("pw","skills"))
# Out:
# skills and pw

# %%
print("{} and {} ".format("pw","skills"))
# Out:
# pw and skills

# %%
print("{}\n{}\n{}\n{}\n{}\n{}".format("800076455","Hii!!","$$Howareyou","10*10=100","(12 >10) and True","I am here to learn 'python"))
# Out:
# 800076455
# Hii!!
# $$Howareyou
# 10*10=100
# (12 >10) and True
# I am here to learn 'python

# %%
print("""800076455
Hii!!
$$Howareyou
10*10=100
(12 >10) and True
I am here to learn 'python""")
# Out:
# 800076455
# Hii!!
# $$Howareyou
# 10*10=100
# (12 >10) and True
# I am here to learn 'python

# %%
print("""
$
$$
$$$
$$$$
$$$$$""")
# Out:
# $
# $$
# $$$
# $$$$
# $$$$$

# %%
x=str(input())
y=x
z="!"+x+"!"
print(z)
# Out:
# cool
# !cool!

# %%
x=input()
y=input()
print(x + "" + y)
# Out:
# po
# pl
# popl

# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
b/a
# Out:
# 2.0

# %%
b//a
# Out:
# 2

# %%
b%a
# Out:
# 0

# %%
a=10

# %%
b=10

# %%
a==b
# Out:
# True

# %%
a is b #identity operator
# Out:
# True

# %%
a=20

# %%
b=30

# %%
a is b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
id(a)
# Out:
# 140704699684232

# %%
id(b)
# Out:
# 140704699684552

# %%
a is b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a =[1,2,3]

# %%
b = [1,2,3]

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
id(a)
# Out:
# 1387534776960

# %%
id(b)
# Out:
# 1387535096128

# %%
a= [1,2,3]

# %%
b=a

# %%
a is b
# Out:
# True

# %%
a ==b
# Out:
# True

# %%
id(a)
# Out:
# 1387535036032

# %%
id(b)
# Out:
# 1387535036032

# %%
a =[2,3,4]

# %%
b=[3,4,2]

# %%
a==b
# Out:
# False

# %%
a is b
# Out:
# False

# %%
x = int(input("enter number: "))
y=3**35//x
print(y)
# Out:
# enter number: 10
# 5003154509899970

# %%
2**2
# Out:
# 4

# %%
a=10

# %%
b=20

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
5%3
# Out:
# 2

# %%
a =10

# %%
b=4

# %%
bin(a)
# Out:
# '0b1010'

# %%
bin(b)
# Out:
# '0b100'

# %%
a&b # bitwise and operator
# Out:
# 0

# %%
a | b # bitwise or operator
# Out:
# 14

# %%
a
# Out:
# 10

# %%
~a
# Out:
# -11

# %%
a^b
# Out:
# 14

# %%
a=10

# %%
b=4

# %%
bin(a)
# Out:
# '0b1010'

# %%
bin(b)
# Out:
# '0b100'

# %%
a ^ b
# Out:
# 14

# %%
a
# Out:
# 10

# %%
a >> 1
# Out:
# 5

# %%
a =10

# %%
a << 1
# Out:
# 20

# %%
a=10

# %%
a
# Out:
# 10

# %%
a =a+1

# %%
a
# Out:
# 11

# %%
a = a+1

# %%
a=10

# %%
a+=3

# %%
a
# Out:
# 13

# %%
a-=3

# %%
a
# Out:
# 10
