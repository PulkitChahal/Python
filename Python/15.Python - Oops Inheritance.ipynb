# %%
class a:
    def test(self):
        print("this test method is a part of class a")
        
    def test1(self):
        print("this is a part of class a")

# %%
obj_a = a()

# %%
obj_a.test()
# Out:
# this test method is a part of class a

# %%
class b(a):
    def test1b(self):
        print("this is a part of class b")

# %%
obj_b = b()

# %%
obj_b.test()
# Out:
# this test method is a part of class a

# %%
obj_b.test1()
# Out:
# this is a part of class a

# %%
obj_b.test1b()
# Out:
# this is a part of class b

# %%
class lecture:
    def topic(self):
        print("todays class we are discussing about inheritance concept in oops")
        
    def timing(self):
        print("timing for todays class is 9 am ist")
        
    def end_time(self):
        print("today i will try to end the class bit early")

# %%
class student(lecture):
    def student_details(self):
        print("this class will give you a student details")

# %%
naval = student()

# %%
naval.topic()
# Out:
# todays class we are discussing about inheritance concept in oops

# %%
naval.timing()
# Out:
# timing for todays class is 9 am ist

# %%
satish = student()

# %%
satish.topic()
satish.timing()
satish.end_time()
satish.student_details()
# Out:
# todays class we are discussing about inheritance concept in oops
# timing for todays class is 9 am ist
# today i will try to end the class bit early
# this class will give you a student details

# %%
class teacher(student):
    def details(self):
        print("this will give you deatils about teacher")

# %%
sudh = teacher()

# %%
sudh.topic()
sudh.timing()
sudh.end_time()
sudh.student_details()
sudh.details()
# Out:
# todays class we are discussing about inheritance concept in oops
# timing for todays class is 9 am ist
# today i will try to end the class bit early
# this class will give you a student details
# this will give you deatils about teacher

# %%
class lecture:
    def topic(self):
        print("todays class we are discussing about inheritance concept in oops")
        
    def timing(self):
        print("timing for todays class is 9 am ist")
        
    def end_time(self):
        print("today i will try to end the class bit early")

# %%
class student:
    def student_details(self):
        print("this class will give you a student details")
        
    def timing(self):
        print("thsi is a timing from student class")

# %%
class teacher(student,lecture):
    def details(self):
        print("this will give you deatils about teacher")

# %%
sudh = teacher()

# %%
sudh.topic()
sudh.timing()
sudh.end_time()
sudh.student_details()
sudh.details()
# Out:
# todays class we are discussing about inheritance concept in oops
# thsi is a timing from student class
# today i will try to end the class bit early
# this class will give you a student details
# this will give you deatils about teacher

# %%
sudh.timing()
# Out:
# thsi is a timing from student class

# %%
class teacher(lecture, student):
    def details(self):
        print("this will give you deatils about teacher")

# %%
krish = teacher()

# %%
krish.timing()
# Out:
# timing for todays class is 9 am ist
