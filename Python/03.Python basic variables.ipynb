# %%
a1 = 45
a2 = 34

# %%
a1+a2
# Out:
# 79

# %%
a1*a2
# Out:
# 1530

# %%
a1-a2
# Out:
# 11

# %%
45/34
# Out:
# 1.3235294117647058

# %%
a1,a2= 34,45

# %%
a1
# Out:
# 34

# %%
a2
# Out:
# 45

# %%
a,b,c,d = 354,'sudh',34,True

# %%
a
# Out:
# 354

# %%
b
# Out:
# 'sudh'

# %%
c
# Out:
# 34

# %%
d
# Out:
# True

# %%
# %a =234
# Out:
# UsageError: Line magic function `%a` not found.

# %%
0b=2342
# Out:
#   Cell In[15], line 1
#     0b=2342
#      ^
# SyntaxError: invalid binary literal

# %%
b0 = 234

# %%
@h = 3543
# Out:
#   Cell In[17], line 1
#     @h = 3543
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
_a = 34

# %%
-b = 234
# Out:
#   Cell In[19], line 1
#     -b = 234
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
True = 45
# Out:
#   Cell In[20], line 1
#     True = 45
#     ^
# SyntaxError: cannot assign to True

# %%
int = 345

# %%
int
# Out:
# 345

# %%
b1 = True #1

# %%
b2 = False

# %%
b1 - b2
# Out:
# 1

# %%
b1/b2
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 b1/b2
#
# ZeroDivisionError: division by zero

# %%
s1 = "my name is pulit"

# %%
s1
# Out:
# 'my name is pulit'

# %%
type(s1)
# Out:
# str

# %%
s2 = "this is my first python code for data science master 's"

# %%
s2
# Out:
# "this is my first python code for data science master 's"

# %%
#this is my cod eto create a string variable with quotes

s3= 'this is my first python class"s'

# %%
s3
# Out:
# 'this is my first python class"s'

# %%
'''this is my firwst python class
i am trying to learn variable declaration
so far i have learnt int , boolean , string , complex number , float variable declaration'''
a=10

# %%
s1 = "sudh"

# %%
a=10

# %%
s1+str(a)
# Out:
# 'sudh10'

# %%
'sudh' + 'kumar'
# Out:
# 'sudhkumar'

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
str(a)
# Out:
# '10'

# %%
s1 +  " " + str(10)
# Out:
# 'sudh 10'

# %%
a
# Out:
# 10

# %%
b =str(a)

# %%
b
# Out:
# '10'

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 int(b)
#
# TypeError: 'int' object is not callable

# %%
s = "sudh"

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 int(s)
#
# TypeError: 'int' object is not callable

# %%
a = 453253

# %%
b = int(input())
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 b = int(input())
#
# TypeError: 'int' object is not callable

# %%
type(int(b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 type(int(b))
#
# TypeError: 'int' object is not callable

# %%
type(b)
# Out:
# str

# %%
d = float(input())
# Out:
# 56

# %%
d
# Out:
# 56.0

# %%
type(d)
# Out:
# float

# %%
s = "sudh"

# %%
s[1]
# Out:
# 'u'

# %%
s[3]
# Out:
# 'h'

# %%
s[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 s[100]
#
# IndexError: string index out of range

# %%
s[-1]
# Out:
# 'h'

# %%
s[-4]
# Out:
# 's'

# %%
s[-345]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 s[-345]
#
# IndexError: string index out of range

# %%
s1 = "pwskills"

# %%
s1[0:2]
# Out:
# 'pw'

# %%
s1[2:7]
# Out:
# 'skill'

# %%
s1[2:]
# Out:
# 'skills'

# %%
s1[2:8000]
# Out:
# 'skills'

# %%
s1[0::2]
# Out:
# 'psil'

# %%
s1[0:8:2]
# Out:
# 'psil'

# %%
s1[7:3]
# Out:
# ''

# %%
s1[7:3:-1]
# Out:
# 'slli'

# %%
s1[-1:-5:-1]
# Out:
# 'slli'

# %%
s1[7:0:-1]
# Out:
# 'slliksw'

# %%
s1[7::-1]
# Out:
# 'sllikswp'

# %%
s1[::-1]
# Out:
# 'sllikswp'

# %%
s1[7:-700:-1]
# Out:
# 'sllikswp'

# %%
s1[-8:-1:-1]
# Out:
# ''

# %%
s1[0]
# Out:
# 'p'

# %%
a=10

# %%
a=20

# %%
a
# Out:
# 20

# %%
s1[0] ='s'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 s1[0] ='s'
#
# TypeError: 'str' object does not support item assignment

# %%
s1 = 'swskills'

# %%
s1[0] = 'p'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 s1[0] = 'p'
#
# TypeError: 'str' object does not support item assignment
