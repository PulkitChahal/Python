# %%
1. build this app in local
2. push this in git
3. deploy on cloud
4. test it

# %%
apikey = '246c1b40ae888a1b6e7e8e4688339905'
url = 'https://api.openweathermap.org/data/2.5/weather'

# %%
params = {'q' : 'delhi',
         'appid': apikey,
         'units':'metric'}

# %%
import requests

# %%
data = requests.get(url, params=params)

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'coord': {'lon': 77.2167, 'lat': 28.6667},
#  'weather': [{'id': 711,
#    'main': 'Smoke',
#    'description': 'smoke',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 23.05,
#   'feels_like': 22.61,
#   'temp_min': 23.05,
#   'temp_max': 23.05,
#   'pressure': 1020,
#   'humidity': 46},
#  'visibility': 1200,
#  'wind': {'speed': 2.06, 'deg': 300},
#  'clouds': {'all': 20},
#  'dt': 1703414545,
#  'sys': {'type': 1,
#   'id': 9165,
#   'country': 'IN',
#   'sunrise': 1703382055,
#   'sunset': 1703419185},
#  'timezone': 19800,
#  'id': 1273294,
#  'name': 'Delhi',
#  'cod': 200}
