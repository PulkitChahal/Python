# %%
## Method definition of the sum function
## Time complexity: O(n)
## Space complexity: O(n)

def summation(arr):
    n = len(arr)
    sumVal = 0
    for i in range(n):
        sumVal += arr[i]
    return sumVal

## Driver code
arr = [23,34,64,12,25,56,68]
result = summation(arr)
print(result)
# Out:
# 282

# %%
arr = [23, 34, 56, 78, 89]
arr.insert(1,24)

# %%
arr
# Out:
# [23, 24, 34, 56, 78, 89]

# %%
arr.remove(24)

# %%
arr
# Out:
# [23, 34, 56, 78, 89]

# %%
## Searching Algorithms
## Time complexity: O(n)
## Space complexity: O(1)

def linearSearch(arr, target):
    for i in range(len(arr)):
        if (arr[i] == target):
            return i
    ## in case element is not available in the array
    return -1

## print -1 [it indicates that the target values in not available in the array]
## Driver code
arr = [12, 14, 16, 18, 11, 22, 26, 29]
target = 30
result = linearSearch(arr, target)
print(result)
# Out:
# -1

# %%
## arr = [2, 5, 11, 13, 15, 18, 22]
## even and odd array containing even num and odd num
## Time complexity: O(n)
## Space complexity: O(n)

## creating an external data structure[list[ to store the even and odd values]]
even = []
odd = []
def evenAndodd(arr):
    ## write your own logic 
    for i in arr:
        if i % 2 == 0:
            even.append(i)
        else:
            odd.append(i)
    return even, odd

## Driver code
arr = [2, 5, 11, 13, 15, 18, 22]
print(evenAndodd(arr))
# Out:
# ([2, 18, 22], [5, 11, 13, 15])

# %%
## function definition
## Time complexity: O(n^2)
## Space complexity: O(1)

def printDiagonalSum(arr):
    n = len(arr)
    primaryDiagonalSum = 0
    secondaryDiagonalSum = 0
    for i in range(n):
        for j in range(n):
            ## condition to get the elements of primary diagonal
            if i == j:
                primaryDiagonalSum += arr[i][j]
                
            ## condotion to get the elements of secondary diagonal
            if ((i+j) == (n-1)):
                secondaryDiagonalSum += arr[i][j]
        
    print("Primary Diagonal Sum :",primaryDiagonalSum)
    print("Secondary Diagonal Sum :",secondaryDiagonalSum)
    
## Driver code
arr = [[2, 4, 6], [8, 11, 13], [14, 17, 19]]
## function calling
n = 3
printDiagonalSum(arr)
# Out:
# Primary Diagonal Sum : 32
# Secondary Diagonal Sum : 31

# %%
## Propeties of Logarithmic
## Asymptonic Notations - Mathematical Idea/Intution
## Arrays - 1D/2D Array
## Random access - Searching abd Sorting[Lnear Search, EvenOdd, Summation, Diagonals]
## Numerous coding problems
## Time and Space Complexity
## Next Session - Binary Search, Sorting Algorithms
## Next Session - Recursion (Can't miss this session)
