# %%
class bankaccount :
    
    def openaccount(hello, name, email_id) :
        print("open an account by taking name and mail id")
        return name + ' ' + email_id
    
    def deposite(hello, amount) :
        print("i am trying to deposite an amount in my account")
        
    def withdraw(hello, amt_with) :
        print("withdraw the amount")
        
    def update_details(hello, name_update, email_update) :
        print("this function will update my name and mail id for account")

# %%
bankaccount().openaccount('sudh', 'sudh@gmail.com')
# Out:
# open an account by taking name and mail id
# 'sudh sudh@gmail.com'

# %%
def test(a,b):
    return a+b

# %%
test(3,4)
# Out:
# 7

# %%
test('sudh','kumar')
# Out:
# 'sudhkumar'

# %%
class pwskills:
    def student(self):
        pass

class datascience(pwskills):
    def student(self):
        print("this will give me a details about data science student")

class bigdata(pwskills):
    def student(self):
        print("this will give me a details about big data student")
  
yash = datascience()
farhana = bigdata()
yash.student()
farhana.student()
# Out:
# this will give me a details about data science student
# this will give me a details about big data student

# %%
class bigdata:
    def __init__(self, number_of_class, number_of_student):
        self.number_of_class = number_of_class
        self.number_of_student = number_of_student
        
    def __add__(self,other):
        return bigdata(self.number_of_class + other.number_of_class, self.number_of_student + other.number_of_student)
    
c1 = bigdata(1,10)
c2 = bigdata(2,12)
c3 = bigdata(2,12)
c4 = bigdata(2,14)
result = c1+c2+c3+c4
print(result.number_of_class, result.number_of_student)
# Out:
# 7 48

# %%
c1

# %%
c2

# %%
result
